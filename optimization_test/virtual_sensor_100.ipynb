# %%
import pandas as pd
import numpy as np
from gurobipy import Model, GRB

# Caricamento dei dati
df = pd.read_csv('../data.csv')
W = 100
t_values = [5566, 5666, 5766, 5866, 5966]

# Liste per salvare i risultati
varianza_prima_ottimizzazione = []
valore_atteso_prima_ottimizzazione = []
varianza_seconda_ottimizzazione = []
valore_atteso_seconda_ottimizzazione = []

# Funzione di callback per interrompere l'ottimizzazione se non ci sono miglioramenti
class MyCallback:
    def __init__(self, max_time_without_improvement, optimization):
        self.last_best_bd = float('inf')
        self.last_improvement_time = 0
        self.max_time_without_improvement = max_time_without_improvement
        self.optimization = optimization
    
    def callback(self, model, where):
        if where == GRB.Callback.MIP:
            best_bd = model.cbGet(GRB.Callback.MIP_OBJBND)
            runtime = model.cbGet(GRB.Callback.RUNTIME)
            if (self.optimization == 0 and abs(best_bd - self.last_best_bd) > 1e-8) or (self.optimization == 1 and abs(best_bd - self.last_best_bd) > 3e-6):  # Verifica miglioramento
                self.last_best_bd = best_bd
                self.last_improvement_time = runtime
                self.last_printed_time = 0  # Reset dell'ultimo tempo stampato
            elif runtime - self.last_improvement_time > self.max_time_without_improvement:
                print("Exceeded the maximum time without significant improvements")
                model.terminate()
            else:
                time_since_last_improvement = runtime - self.last_improvement_time
                next_multiple_of_60 = (self.last_printed_time // 60 + 1) * 60
                if time_since_last_improvement >= next_multiple_of_60:
                    self.last_printed_time = time_since_last_improvement
                    minutes_since_last_improvement = time_since_last_improvement // 60
                    print(f"{minutes_since_last_improvement:.1f} minute(s) with no significant improvement")
                    print(f"Last significant improvement time: {self.last_improvement_time}")
                    print(f"Current bound: {best_bd}")

# Funzione per eseguire le ottimizzazioni e stampare i risultati
def optimize_and_save_results(t):
    # Filtraggio dei dati per la finestra temporale
    window_data = df[(df['SampleTime'] >= t - W) & (df['SampleTime'] <= t)]

    # Pivot table per avere un formato adatto all'ottimizzazione
    pivot_data = window_data.pivot(index='SampleTime', columns='SensorID', values='Value').fillna(0)

    # Calcolo della penalizzazione basata sul numero di valori nulli originali
    null_counts = window_data.pivot(index='SampleTime', columns='SensorID', values='Value').isna().sum()
    penalty = null_counts / null_counts.max()  # Normalizzare la penalizzazione tra 0 e 1

    # Filtrare le colonne con tutti valori nulli
    pivot_data = pivot_data.dropna(axis=1, how='all')

    # Calcolo di media e varianza
    mean_vector = pivot_data.mean(axis=0, skipna=True).values
    cov_matrix = pivot_data.cov().values

    # Creare un dizionario per la penalizzazione con i nuovi indici
    penalty_dict = penalty[pivot_data.columns].to_dict()

    # Definizione dei parametri
    n = len(mean_vector)
    B = 10
    delta = 0.001 # Soglia minima per alpha

    # Numero di thread da utilizzare
    num_threads = 8
    max_time_without_improvement = 600  # Tempo in secondi per fermare se BestBd non viene aggiornato

    # Creazione del modello per la prima ottimizzazione
    model1 = Model()

    # Impostazione del numero di thread e del callback
    model1.setParam('Threads', num_threads)

    # Aggiunta delle variabili
    alpha1 = model1.addVars(n, lb=0, ub=1, name="alpha1")
    b1 = model1.addVars(n, vtype=GRB.BINARY, name="b1")

    # Funzione obiettivo: minimizzare la varianza di Y
    var_Y1 = sum(alpha1[i] * alpha1[j] * cov_matrix[i, j] for i in range(n) for j in range(n))
    penalized_var_Y1 = var_Y1 + sum(penalty_dict[pivot_data.columns[i]] * alpha1[i] for i in range(n))  # Aggiungere la penalizzazione
    model1.setObjective(penalized_var_Y1, GRB.MINIMIZE)

    # Vincoli
    model1.addConstr(sum(alpha1[i] for i in range(n)) == 1, "sum_alpha1")
    model1.addConstr(sum(b1[i] for i in range(n)) == B, "sum_b1")
    for i in range(n):
        model1.addConstr(alpha1[i] <= b1[i], f"alpha1_b1_{i}")
        model1.addConstr(alpha1[i] >= delta * b1[i], f"alpha1_min_{i}")  # Nuovo vincolo per la soglia minima di alpha

    # Risoluzione del modello con callback
    callback1 = MyCallback(max_time_without_improvement, 0)
    model1.optimize(callback1.callback)

    # Estrazione dei risultati della prima ottimizzazione
    alpha_values1 = model1.getAttr('x', alpha1)
    b_values1 = model1.getAttr('x', b1)
    selected_sensors1 = [(pivot_data.columns[i], alpha_values1[i]) for i in range(n) if alpha_values1[i] > 0]

    # Calcolo della varianza minima ottenuta
    varianza_minima = sum(alpha_values1[i] * alpha_values1[j] * cov_matrix[i, j] for i in range(n) for j in range(n))

    # Calcolo del valore atteso dopo la prima ottimizzazione
    expected_value1 = sum(alpha_values1[i] * mean_vector[i] for i in range(n))

    # Salvataggio dei risultati della prima ottimizzazione
    varianza_prima_ottimizzazione.append(varianza_minima)
    valore_atteso_prima_ottimizzazione.append(expected_value1)

    # Stampa dei risultati della prima ottimizzazione
    print(f"Risultati Prima Ottimizzazione per t = {t}:")
    print("I 10 alpha diversi da 0 con i relativi SensorID:")
    for i, val in sorted(selected_sensors1, key=lambda x: x[1], reverse=True)[:10]:
        print(f"SensorID: {i}, alpha: {val}")
    alpha_sum1 = sum(val for _, val in selected_sensors1)
    print(f"Somma degli alpha diversi da 0: {alpha_sum1}")
    print(f"Varianza: {varianza_minima}")
    print(f"Valore atteso: {expected_value1}")

    # Creazione del modello per la seconda ottimizzazione
    model2 = Model()

    # Impostazione del numero di thread e del callback
    model2.setParam('Threads', num_threads)

    # Aggiunta delle variabili
    alpha2 = model2.addVars(n, lb=0, ub=1, name="alpha2")
    b2 = model2.addVars(n, vtype=GRB.BINARY, name="b2")

    # Funzione obiettivo: massimizzare il valore atteso di Y
    expected_Y = sum(alpha2[i] * mean_vector[i] for i in range(n))
    penalized_expected_Y = expected_Y - sum(penalty_dict[pivot_data.columns[i]] * alpha2[i] for i in range(n))  # Aggiungere la penalizzazione
    model2.setObjective(penalized_expected_Y, GRB.MAXIMIZE)

    # Vincoli
    model2.addConstr(sum(alpha2[i] for i in range(n)) == 1, "sum_alpha2")
    model2.addConstr(sum(b2[i] for i in range(n)) <= B, "sum_b2")
    for i in range(n):
        model2.addConstr(alpha2[i] <= b2[i], f"alpha2_b2_{i}")
        model2.addConstr(alpha2[i] >= delta * b2[i], f"alpha2_min_{i}")  # Nuovo vincolo per la soglia minima di alpha

    # Vincolo sulla varianza con tolleranza
    epsilon = 1e-6
    var_Y2 = sum(alpha2[i] * alpha2[j] * cov_matrix[i, j] for i in range(n) for j in range(n))
    model2.addConstr(var_Y2 <= varianza_minima - epsilon, "var_constraint")

    # Risoluzione del modello con callback
    callback2 = MyCallback(max_time_without_improvement, 1)
    model2.optimize(callback2.callback)

    # Estrazione dei risultati della seconda ottimizzazione
    alpha_values2 = model2.getAttr('x', alpha2)
    b_values2 = model2.getAttr('x', b2)
    selected_sensors2 = [(pivot_data.columns[i], alpha_values2[i]) for i in range(n) if alpha_values2[i] > 0]

    # Calcolo del valore atteso e della varianza ottenuti
    expected_value2 = sum(alpha_values2[i] * mean_vector[i] for i in range(n))
    varianza_seconda_ottimizzazione_value = sum(alpha_values2[i] * alpha_values2[j] * cov_matrix[i, j] for i in range(n) for j in range(n))

    # Verifica del vincolo di varianza
    if varianza_seconda_ottimizzazione_value > varianza_minima:
        print("Errore: la varianza dopo la seconda ottimizzazione è maggiore della varianza minima!")
    else:
        print("Il vincolo di varianza è rispettato.")

    # Salvataggio dei risultati della seconda ottimizzazione
    varianza_seconda_ottimizzazione.append(varianza_seconda_ottimizzazione_value)
    valore_atteso_seconda_ottimizzazione.append(expected_value2)

    # Stampa dei risultati della seconda ottimizzazione
    print(f"Risultati Seconda Ottimizzazione per t = {t}:")
    print("I 10 alpha diversi da 0 con i relativi SensorID:")
    for i, val in sorted(selected_sensors2, key=lambda x: x[1], reverse=True)[:10]:
        print(f"SensorID: {i}, alpha: {val}")
    alpha_sum2 = sum(val for _, val in selected_sensors2)
    print(f"Somma degli alpha diversi da 0: {alpha_sum2}")
    print(f"Varianza: {varianza_seconda_ottimizzazione_value}")
    print(f"Valore atteso: {expected_value2}")


# Esecuzione del ciclo per ogni valore di t
for t in t_values:
    print(f"Esecuzione per t = {t}")
    optimize_and_save_results(t)
# Out:
# Esecuzione per t = 5100
# Set parameter Threads to value 8
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1844 rows, 1842 columns and 5526 nonzeros
# Model fingerprint: 0x8a45fdf9
# Model has 424581 quadratic objective terms
# Variable types: 921 continuous, 921 integer (921 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [2e-02, 1e+00]
#   QObjective range [2e-10, 5e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 0.0715394
# Presolve time: 0.13s
# Presolved: 1844 rows, 1842 columns, 5526 nonzeros
# Presolved model has 424581 quadratic objective terms
# Variable types: 921 continuous, 921 integer (921 binary)
# Warning: 1 variables dropped from basis
#
# Root relaxation: objective 6.292493e-07, 5925 iterations, 1.38 seconds (3.20 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                       0.0001297    0.00000   100%     -    1s
#      0     0    0.00000    0   40    0.00013    0.00000   100%     -    1s
# H    0     0                       0.0000511    0.00000  98.8%     -    2s
#      0     0    0.00000    0   39    0.00005    0.00000  98.7%     -    2s
# H    0     0                       0.0000045    0.00000  85.4%     -    3s
# H    0     0                       0.0000043    0.00000  84.7%     -    3s
# H    0     0                       0.0000024    0.00000  72.8%     -    3s
#      0     0    0.00000    0   39    0.00000    0.00000  72.6%     -    4s
# H    0     0                       0.0000016    0.00000  58.4%     -    4s
#      0     2    0.00000    0   39    0.00000    0.00000  58.4%     -    4s
#      1     4    0.00000    1   41    0.00000    0.00000  56.3%   228    5s
#      7    16    0.00000    3   41    0.00000    0.00000  56.1%  2661   10s
#  36049  5895    0.00000   46   37    0.00000    0.00000  14.3%   189  640s
# 9.0 minute(s) with no significant improvement
# Last significant improvement time: 101.64598488807678
# Current bound: 9.90801137552296e-07
#  37361  6025     cutoff   70         0.00000    0.00000  14.3%   188  654s
#  38766  6348    0.00000   65   31    0.00000    0.00000  14.3%   187  668s
#  40045  6544    0.00000   61   32    0.00000    0.00000  14.3%   186  681s
#  41283  6828     cutoff   42         0.00000    0.00000  14.3%   186  694s
# Exceeded the maximum time without significant improvements
#  42648  7115     cutoff   55         0.00000    0.00000  14.3%   184  708s
#
# Cutting planes:
#   Implied bound: 2
#   MIR: 1
#   Flow cover: 1
#
# Explored 43978 nodes (8011291 simplex iterations) in 708.43 seconds (1317.26 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.15665e-06 1.19356e-06 1.24292e-06 ... 1.58118e-06
#
# Solve interrupted
# Best objective 1.156653143562e-06, best bound 9.908011375523e-07, gap 14.3390%
#
# User-callback calls 171468, time in user-callback 1.03 sec
# Risultati Prima Ottimizzazione per t = 5100:
# I 10 alpha diversi da 0 con i relativi SensorID:
# SensorID: 30, alpha: 0.20191651636528798
# SensorID: 31, alpha: 0.18508867939601784
# SensorID: 325, alpha: 0.16709412872937507
# SensorID: 240, alpha: 0.12400716147946167
# SensorID: 376, alpha: 0.11757640350139276
# SensorID: 195, alpha: 0.09679784506995556
# SensorID: 115, alpha: 0.03476225615256226
# SensorID: 988, alpha: 0.03206281721548472
# SensorID: 285, alpha: 0.027974420260896117
# SensorID: 58, alpha: 0.012719771829566002
# Somma degli alpha diversi da 0: 1.0
# Varianza: 1.156653143562045e-06
# Valore atteso: 0.0004273469931489507
# Set parameter Threads to value 8
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1844 rows, 1842 columns and 5526 nonzeros
# Model fingerprint: 0xf3fbc012
# Model has 1 quadratic constraint
# Variable types: 921 continuous, 921 integer (921 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   QMatrix range    [1e-10, 3e-02]
#   Objective range  [4e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [2e-07, 2e-07]
# Presolve time: 0.24s
# Presolved: 1844 rows, 1842 columns, 5526 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Variable types: 921 continuous, 921 integer (921 binary)
#
# Root relaxation: objective 1.843192e-02, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.01843    0    -          -    0.01843      -     -    0s
#      0     0    0.00838    0    -          -    0.00838      -     -    0s
#      0     0    0.00773    0    -          -    0.00773      -     -    0s
#      0     0    0.00595    0    1          -    0.00595      -     -    0s
#      0     0    0.00420    0    -          -    0.00420      -     -    1s
#      0     0    0.00420    0    -          -    0.00420      -     -    1s
#      0     0    0.00420    0    1          -    0.00420      -     -    1s
#      0     0    0.00326    0    -          -    0.00326      -     -    4s
#      0     0    0.00326    0    -          -    0.00326      -     -    4s
#      0     0    0.00326    0    -          -    0.00326      -     -    4s
#      0     0    0.00326    0    4          -    0.00326      -     -    5s
#      0     0    0.00326    0    5          -    0.00326      -     -    7s
# H    0     0                      -0.8373953    0.00326   100%     -   14s
#      0     0    0.00326    0    5   -0.83740    0.00326   100%     -   15s
# H    0     0                      -0.7753599    0.00326   100%     -   16s
#      0     2    0.00315    0    3   -0.77536    0.00315   100%     -   18s
# H   31    40                      -0.6692659    0.00315   100%   4.6   26s
# H   32    40                      -0.5400573    0.00315   101%   4.5   26s
# H   34    40                      -0.5156064    0.00315   101%   4.4   26s
#    226   187 infeasible   27        -0.51561    0.00315   101%  16.5   30s
#    537   377 infeasible   55        -0.51561    0.00315   101%  16.9   35s
# H  539   377                      -0.3495804    0.00315   101%  17.4   35s
#    935   617   -0.00546   95   15   -0.34958    0.00315   101%  18.0   40s
#   1200   765   -0.33459   38   57   -0.34958   -0.33459  4.29%  18.3   50s
#   1201   766   -0.33459   83   57   -0.34958   -0.33459  4.29%  18.2   62s
#   1204   769     cutoff   12        -0.34958   -0.33460  4.29%  18.2   76s
#   1212   768     cutoff   16        -0.34958   -0.33460  4.29%  18.1   80s
#   1236   768   -0.34793   20   52   -0.34958   -0.33460  4.29%  17.7   86s
#   1260   760     cutoff   23        -0.34958   -0.33460  4.28%  17.4   90s
#
# Cutting planes:
#   Flow cover: 1
#   Relax-and-lift: 2
#
# Explored 1282 nodes (21980 simplex iterations) in 91.78 seconds (46.94 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: -0.34958 -0.515606 -0.540057 ... -0.837395
# No other solutions better than -0.34958
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.495804377098e-01, best bound -3.495804377098e-01, gap 0.0000%
#
# User-callback calls 17161, time in user-callback 0.08 sec
# Il vincolo di varianza è rispettato.
# Risultati Seconda Ottimizzazione per t = 5100:
# I 10 alpha diversi da 0 con i relativi SensorID:
# SensorID: 33, alpha: 0.35004308765703857
# SensorID: 30, alpha: 0.24848934875679554
# SensorID: 31, alpha: 0.2269361445202013
# SensorID: 115, alpha: 0.06064217389355401
# SensorID: 521, alpha: 0.040015405593685174
# SensorID: 285, alpha: 0.029219908220290344
# SensorID: 482, alpha: 0.02664365774518227
# SensorID: 266, alpha: 0.014132096550226446
# SensorID: 276, alpha: 0.0028781770630270423
# SensorID: 503, alpha: 0.0009999999999993348
# Somma degli alpha diversi da 0: 1.0
# Varianza: 1.0915740813065033e-06
# Valore atteso: 0.000462649947227828
# Esecuzione per t = 5200
# Set parameter Threads to value 8
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1864 rows, 1862 columns and 5586 nonzeros
# Model fingerprint: 0x74dac9d8
# Model has 432915 quadratic objective terms
# Variable types: 931 continuous, 931 integer (931 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [2e-02, 1e+00]
#   QObjective range [4e-09, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 0.0024882
# Presolve time: 0.13s
# Presolved: 1864 rows, 1862 columns, 5586 nonzeros
# Presolved model has 432915 quadratic objective terms
# Variable types: 931 continuous, 931 integer (931 binary)
#
# Root relaxation: objective 5.340800e-05, 88 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00005    0   15    0.00249    0.00005  97.9%     -    0s
# H    0     0                       0.0000530    0.00005  0.00%     -    0s
#      0     0    0.00005    0   15    0.00005    0.00005  0.00%     -    0s
#
# Explored 1 nodes (88 simplex iterations) in 0.23 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5.30335e-05 0.00248821
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.303352459595e-05, best bound 5.303352459595e-05, gap 0.0000%
#
# User-callback calls 213, time in user-callback 0.00 sec
# Risultati Prima Ottimizzazione per t = 5200:
# I 10 alpha diversi da 0 con i relativi SensorID:
# SensorID: 195, alpha: 0.4384912545778985
# SensorID: 733, alpha: 0.11234248794612003
# SensorID: 572, alpha: 0.11024061584406475
# SensorID: 353, alpha: 0.07367182676079052
# SensorID: 831, alpha: 0.05932598012634547
# SensorID: 995, alpha: 0.05302889779251093
# SensorID: 521, alpha: 0.049152915421176294
# SensorID: 386, alpha: 0.04193007924039754
# SensorID: 129, alpha: 0.0348146987677554
# SensorID: 605, alpha: 0.027001243522940695
# Somma degli alpha diversi da 0: 1.0
# Varianza: 5.303352459594701e-05
# Valore atteso: 0.0016332614949212901
# Set parameter Threads to value 8
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1864 rows, 1862 columns and 5586 nonzeros
# Model fingerprint: 0xbd7083d2
# Model has 1 quadratic constraint
# Variable types: 931 continuous, 931 integer (931 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   QMatrix range    [2e-09, 5e-02]
#   Objective range  [3e-06, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [5e-05, 5e-05]
# Presolve time: 0.24s
# Presolved: 1864 rows, 1862 columns, 5586 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Variable types: 931 continuous, 931 integer (931 binary)
#
# Root relaxation: objective 9.994267e-03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00999    0    -          -    0.00999      -     -    0s
#      0     0    0.00900    0    -          -    0.00900      -     -    0s
#      0     0    0.00813    0    -          -    0.00813      -     -    0s
#      0     0    0.00809    0    -          -    0.00809      -     -    0s
#      0     0    0.00788    0    -          -    0.00788      -     -    0s
#      0     0    0.00713    0    -          -    0.00713      -     -    0s
#      0     0    0.00667    0    -          -    0.00667      -     -    0s
#      0     0    0.00635    0    -          -    0.00635      -     -    0s
#      0     0    0.00562    0    -          -    0.00562      -     -    0s
#      0     0    0.00545    0    -          -    0.00545      -     -    0s
#      0     0    0.00521    0    1          -    0.00521      -     -    0s
#      0     0    0.00507    0    2          -    0.00507      -     -    1s
#      0     0    0.00494    0    3          -    0.00494      -     -    3s
#      0     0    0.00482    0    2          -    0.00482      -     -    3s
#      0     0    0.00482    0    2          -    0.00482      -     -    4s
#      0     0    0.00470    0    -          -    0.00470      -     -    4s
#      0     0    0.00461    0    3          -    0.00461      -     -    4s
#      0     0    0.00461    0    3          -    0.00461      -     -    4s
#      0     0    0.00461    0    3          -    0.00461      -     -    9s
#      0     0    0.00461    0    3          -    0.00461      -     -   10s
#      0     2    0.00426    0    7          -    0.00426      -     -   12s
#    189   151    0.00299   20    -          -    0.00390      -   7.1   15s
# H  285   215                      -0.4563344    0.00390   101%   7.0   16s
# *  285   215              27      -0.4563344    0.00390   101%   7.0   16s
# H  295   217                      -0.3766139    0.00390   101%   6.9   16s
# *  295   217              28      -0.3766139    0.00390   101%   7.0   16s
#    300   221    0.00256   16    -   -0.37661    0.00390   101%   7.4   23s
# H  302   222                      -0.2455489    0.00390   102%   7.4   23s
# H  303   222                      -0.2278973    0.00390   102%   7.4   23s
# H  309   223                      -0.1458494    0.00390   103%   8.0   23s
# H  312   223                      -0.1128656    0.00390   103%   8.3   23s
#    405   306    0.00278   26    4   -0.11287    0.00390   103%   8.5   25s
# H  623   382                      -0.0480732    0.00390   108%   8.8   28s
#    624   383    0.00384    5    3   -0.04807    0.00390   108%   8.8   39s
#    626   384    0.00360    6    5   -0.04807    0.00360   107%   8.8   47s
# H  626   364                      -0.0480023    0.00360   107%   8.8   54s
work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: -0.00129164 -0.00654617 -0.0134444 ... -0.227897
# No other solutions better than -0.00129164
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.291640712769e-03, best bound -1.291640712769e-03, gap 0.0000%
#
# User-callback calls 117495, time in user-callback 0.34 sec
# Il vincolo di varianza è rispettato.
# Risultati Seconda Ottimizzazione per t = 5200:
# I 10 alpha diversi da 0 con i relativi SensorID:
# SensorID: 195, alpha: 0.4823198249007396
# SensorID: 733, alpha: 0.1256356885874126
# SensorID: 572, alpha: 0.09434471618401498
# SensorID: 353, alpha: 0.07344820696378292
# SensorID: 995, alpha: 0.05708990030298182
# SensorID: 831, alpha: 0.050048554985190716
# SensorID: 129, alpha: 0.045792363093268694
# SensorID: 285, alpha: 0.03252054396224016
# SensorID: 605, alpha: 0.02995218572283065
# SensorID: 677, alpha: 0.00884801529753783
# Somma degli alpha diversi da 0: 0.9999999999999999
# Varianza: 5.297562812207816e-05
# Valore atteso: 0.0018051646413695228
# Esecuzione per t = 5300
# Set parameter Threads to value 8
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1892 rows, 1890 columns and 5670 nonzeros
# Model fingerprint: 0xdfce541d
# Model has 446985 quadratic objective terms
# Variable types: 945 continuous, 945 integer (945 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   Objective range  [7e-02, 1e+00]
#   QObjective range [1e-09, 3e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 0.0000255
# Presolve time: 0.13s
# Presolved: 1892 rows, 1890 columns, 5670 nonzeros
# Presolved model has 446985 quadratic objective terms
# Variable types: 945 continuous, 945 integer (945 binary)
#
# Root relaxation: objective 5.168301e-06, 161 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00001    0   26    0.00003    0.00001  79.7%     -    0s
# H    0     0                       0.0000057    0.00001  9.68%     -    0s
#      0     0    0.00001    0   26    0.00001    0.00001  9.68%     -    0s
# H    0     0                       0.0000057    0.00001  8.86%     -    1s
#      0     0    0.00001    0   25    0.00001    0.00001  8.86%     -    1s
# H    0     0                       0.0000056    0.00001  8.17%     -    1s
#      0     2    0.00001    0   25    0.00001    0.00001  8.17%     -    1s
# H  682   135                       0.0000056    0.00001  7.94%  23.5    3s
#   1599   261    0.00001   16   20    0.00001    0.00001  7.94%  21.7    5s
#   4048   561    0.00001   12   27    0.00001    0.00001  7.94%  22.2   10s
#   6298   365     cutoff   47         0.00001    0.00001  7.94%  20.7   15s
#   9772   777    0.00001   31   11    0.00001    0.00001  6.41%  19.5   20s
#  13446  1330    0.00001   28   14    0.00001    0.00001  6.39%  18.5   25s
#  16800  1712    0.00001   34   11    0.00001    0.00001  5.64%  17.9   30s
#  21018  1971    0.00001   33   13    0.00001    0.00001  4.98%  17.3   35s
#  25298  2220    0.00001   21   17    0.00001    0.00001  4.49%  17.0   40s
#  29851  2392     cutoff   26         0.00001    0.00001  4.15%  16.9   47s
#  32570  2499    0.00001   33   13    0.00001    0.00001  4.08%  16.7   50s
#  37193  2602     cutoff   28         0.00001    0.00001  3.69%  16.5   55s
#  41251  2841     cutoff   31         0.00001    0.00001  3.69%  16.3   60s
#  45128  2920    0.00001   27   17    0.00001    0.00001  3.61%  16.2   65s
#  50407  2889    0.00001   31   12    0.00001    0.00001  3.28%  16.0   70s
#  54535  3034    0.00001   32   13    0.00001    0.00001  3.13%  15.8   75s
#  59360  3124    0.00001   34   14    0.00001    0.00001  2.96%  15.7   80s
#  64163  3137    0.00001   25   15    0.00001    0.00001  2.69%  15.6   85s
#  67932  3221     cutoff   39         0.00001    0.00001  2.57%  15.5   90s
#  72831  3249     cutoff   36         0.00001    0.00001  2.42%  15.4   95s
#  77048  3217     cutoff   24         0.00001    0.00001  2.25%  15.4  100s
#  81563  3242     cutoff   25         0.00001    0.00001  2.10%  15.2  105s
#  85575  3294    0.00001   29   14    0.00001    0.00001  1.97%  15.2  110s
#  89933  3240    0.00001   32   14    0.00001    0.00001  1.82%  15.1  115s
#  94804  3152    0.00001   31   15    0.00001    0.00001  1.69%  15.1  120s
#  99739  3010    0.00001   29   17    0.00001    0.00001  1.56%  15.0  125s
#  104040  2899     cutoff   38         0.00001    0.00001  1.42%  14.9  130s
#  108818  2674     cutoff   40         0.00001    0.00001  1.24%  14.8  135s
#  113842  2364     cutoff   33         0.00001    0.00001  1.04%  14.7  140s
#  117120  2115    0.00001   26   17    0.00001    0.00001  0.94%  14.7  145s
#  122297  1663    0.00001   34   13    0.00001    0.00001  0.72%  14.6  150s
#  126817  1087    0.00001   41    8    0.00001    0.00001  0.51%  14.5  155s
#  131813   311     cutoff   27         0.00001    0.00001  0.26%  14.3  160s
#
# Explored 133765 nodes (1913613 simplex iterations) in 161.83 seconds (137.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 5.63327e-06 5.63432e-06 5.67097e-06 ... 2.54949e-05
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.633272212132e-06, best bound 5.633272212132e-06, gap 0.0000%
#
# User-callback calls 277714, time in user-callback 0.73 sec
# Risultati Prima Ottimizzazione per t = 5300:
# I 10 alpha diversi da 0 con i relativi SensorID:
# SensorID: 348, alpha: 0.23478308229085626
# SensorID: 195, alpha: 0.1944023246295875
# SensorID: 32, alpha: 0.19227601540779618
# SensorID: 240, alpha: 0.11903094553568919
# SensorID: 572, alpha: 0.09010931468259756
# SensorID: 261, alpha: 0.0564883888336514
# SensorID: 922, alpha: 0.03536688742387279
# SensorID: 514, alpha: 0.03127181325183098
# SensorID: 147, alpha: 0.02399909819159489
# SensorID: 94, alpha: 0.022272129752523146
# Somma degli alpha diversi da 0: 1.0
# Varianza: 5.633272212131952e-06
# Valore atteso: 0.0006285236650077695
# Set parameter Threads to value 8
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1892 rows, 1890 columns and 5670 nonzeros
# Model fingerprint: 0x4ef0c7c4
# Model has 1 quadratic constraint
# Variable types: 945 continuous, 945 integer (945 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+00]
#   QMatrix range    [7e-10, 1e-02]
#   Objective range  [1e-05, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [5e-06, 5e-06]
# Presolve time: 0.26s
# Presolved: 1892 rows, 1890 columns, 5670 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Variable types: 945 continuous, 945 integer (945 binary)
#
# Root relaxation: objective 1.909843e-02, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0
#  1799814 1012461     cutoff   85        -0.04536    0.00098   102%  31.4 15962s
#  1800905 1012751   -0.00884   84   19   -0.04536    0.00098   102%  31.4 15969s
#  1801372 1012848   -0.02435   81   15   -0.04536    0.00098   102%  31.4 15981s
#  1801546 1013422   -0.00654   67   20   -0.04536    0.00098   102%  31.4 15988s
#  1802456 1013919    0.00066   63   18   -0.04536    0.00098   102%  31.4 15997s
# 9.0 minute(s) with no significant improvement
# Last significant improvement time: 15463.085509061813
# Current bound: 0.0009783892970110185
#  1803667 1014638   -0.00089   63   17   -0.04536    0.00098   102%  31.4 16004s
#  1804793 1014846    0.00050   69   18   -0.04536    0.00098   102%  31.4 16012s
# H1804797 1014846                      -0.0453551    0.00098   102%  31.4 16012s
#  1805082 1015368     cutoff   90        -0.04536    0.00098   102%  31.4 16019s
#  1805923 1015729   -0.01157   69   18   -0.04536    0.00098   102%  31.4 16027s
#  1806960 1015880 infeasible   80        -0.04536    0.00098   102%  31.4 16039s
#  1807234 1016420   -0.01424   74   21   -0.04536    0.00098   102%  31.4 16047s
#  1808368 1017116   -0.00302   76   20   -0.04536    0.00098   102%  31.4 16055s
# Exceeded the maximum time without significant improvements
#  1809510 1017205    0.00029   66   17   -0.04536    0.00098   102%  31.4 16063s
#
# Cutting planes:
#   Flow cover: 1
#   Inf proof: 126
#
# Explored 1809687 nodes (56887692 simplex iterations) in 16063.99 seconds (13764.73 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: -0.0453551 -0.0513002 -0.0809368 ... -0.12283
#
# Solve interrupted
# Best objective -4.535512168371e-02, best bound 9.781530020239e-04, gap 102.1567%
#
# User-callback calls 5024480, time in user-callback 15.86 sec
# Il vincolo di varianza è rispettato.
# Risultati Seconda Ottimizzazione per t = 5500:
# I 10 alpha diversi da 0 con i relativi SensorID:
# SensorID: 844, alpha: 0.22412884042525838
# SensorID: 753, alpha: 0.14609000534284838
# SensorID: 361, alpha: 0.13501761582128402
# SensorID: 404, alpha: 0.11048595223986653
# SensorID: 261, alpha: 0.10001849243733876
# SensorID: 752, alpha: 0.09010669376285774
# SensorID: 514, alpha: 0.0692925984970144
# SensorID: 178, alpha: 0.06567783831083696
# SensorID: 111, alpha: 0.035912837259054864
# SensorID: 386, alpha: 0.02326912590363962
# Somma degli alpha diversi da 0: 0.9999999999999996
# Varianza: 1.948868605104868e-06
# Valore atteso: 0.00025448825436975397

# %%
# Caricamento dei dati
df = pd.read_csv('../data.csv')
W = 100
t_values = [5566, 5666, 5766, 5866, 5966]

# Liste per salvare i risultati
varianza_senza_ottimizzazione = []
valore_atteso_senza_ottimizzazione = []

# Funzione per calcolare varianza e valore atteso senza ottimizzazione
def calculate_without_optimization(t):
    # Filtraggio dei dati per la finestra temporale da t a t + W
    new_window_data = df[(df['SampleTime'] >= t) & (df['SampleTime'] <= t + W)]

    # Pivot table per avere un formato adatto al calcolo
    new_pivot_data = new_window_data.pivot(index='SampleTime', columns='SensorID', values='Value')

    # Calcolo di media e varianza per la nuova finestra temporale
    new_mean_vector = new_pivot_data.mean(axis=0, skipna=True).values
    new_cov_matrix = new_pivot_data.cov().values

    # Calcolo del valore atteso e della varianza senza applicare l'ottimizzazione degli alpha
    expected_value = np.nanmean(new_mean_vector)  # Media dei valori dei sensori
    variance = np.nanmean(new_cov_matrix)  # Media della matrice di covarianza

    # Salvataggio dei risultati
    varianza_senza_ottimizzazione.append(variance)
    valore_atteso_senza_ottimizzazione.append(expected_value)

    # Stampa dei risultati
    print(f"Risultati senza ottimizzazione per t = {t}:")
    print(f"Varianza: {variance}")
    print(f"Valore atteso: {expected_value}")

# Esecuzione del ciclo per ogni valore di t
for t in t_values:
    print(f"Esecuzione per t = {t}")
    calculate_without_optimization(t)

# Risultati finali
print("Risultati finali senza ottimizzazione:")
print(f"Varianza Senza Ottimizzazione: {varianza_senza_ottimizzazione}")
print(f"Valore Atteso Senza Ottimizzazione: {valore_atteso_senza_ottimizzazione}")
# Out:
# Esecuzione per t = 5100
# Risultati senza ottimizzazione per t = 5100:
# Varianza: 0.0008775683300031
# Valore atteso: 0.0002678958160414811
# Esecuzione per t = 5200
# Risultati senza ottimizzazione per t = 5200:
# Varianza: 8.94358829459538e-05
# Valore atteso: 0.0018186046814604297
# Esecuzione per t = 5300
# Risultati senza ottimizzazione per t = 5300:
# Varianza: 6.950238307966231e-05
# Valore atteso: 0.0018888130365442683
# Esecuzione per t = 5400
# Risultati senza ottimizzazione per t = 5400:
# Varianza: 4.579255168813282e-05
# Valore atteso: 0.0008971692429056186
# Esecuzione per t = 5500
# Risultati senza ottimizzazione per t = 5500:
# Varianza: 7.379850855868417e-05
# Valore atteso: 2.5033442451482288e-05
# Risultati finali senza ottimizzazione:
# Varianza Senza Ottimizzazione: [0.0008775683300031, 8.94358829459538e-05, 6.950238307966231e-05, 4.579255168813282e-05, 7.379850855868417e-05]
# Valore Atteso Senza Ottimizzazione: [0.0002678958160414811, 0.0018186046814604297, 0.0018888130365442683, 0.0008971692429056186, 2.5033442451482288e-05]

# %%
import matplotlib.pyplot as plt

# Offset per evitare sovrapposizioni complete
offset = 4e-7

# Applicazione degli offset alle varianze
varianza_prima_offset = [v + offset for v in varianza_prima_ottimizzazione]
varianza_seconda_offset = [v - offset for v in varianza_seconda_ottimizzazione]

# Plot della varianza
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(t_values, varianza_prima_offset, label='Varianza Prima Ottimizzazione', marker='o')
plt.plot(t_values, varianza_seconda_offset, label='Varianza Seconda Ottimizzazione', marker='o')
plt.plot(t_values, varianza_senza_ottimizzazione, label='Varianza Senza Ottimizzazione', marker='o')
plt.xlabel('t')
plt.ylabel('Varianza')
plt.title('Varianza al variare di t')
plt.legend()
plt.grid(True)

# Plot del valore atteso
plt.subplot(1, 2, 2)
plt.plot(t_values, valore_atteso_prima_ottimizzazione, label='Valore Atteso Prima Ottimizzazione', marker='o')
plt.plot(t_values, valore_atteso_seconda_ottimizzazione, label='Valore Atteso Seconda Ottimizzazione', marker='o')
plt.plot(t_values, valore_atteso_senza_ottimizzazione, label='Valore Atteso Senza Ottimizzazione', marker='o')
plt.xlabel('t')
plt.ylabel('Valore Atteso')
plt.title('Valore Atteso al variare di t')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
